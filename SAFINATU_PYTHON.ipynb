# %% [markdown]
# <a href="https://colab.research.google.com/github/Eddie-Anna/Ant-Feeding-Simulation-NetLogo/blob/SKILL-SET/SAFINATU_PYTHON.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #**INTRODUCTION**

# %% [markdown]
# Welcome to Python for Data Analysis

# %% [markdown]
# I like this class

# %%
print(3+7)
print(5*2)
# Out:
# 10
# 10

# %%
# This is a
3+7
# Out:
# 10

# %%
print(7)
# Out:
# 7

# %% [markdown]
# # Fundmentals of Python 3

# %%
print(20)
# Out:
# 20

# %%
print(3+6)
# Out:
# 9

# %%
print(0.85)
# Out:
# 0.85

# %%
print(1e6)
print(1E9)
# Out:
# 1000000.0
# 1000000000.0

# %%
print(1e-3)
print(1e-5)
print(1E-9)
# Out:
# 0.001
# 1e-05
# 1e-09

# %%
print("HELLO WORLD")
print("LADY")
# Out:
# HELLO WORLD
# LADY

# %%
print("PRAISE")
# Out:
# PRAISE

# %% [markdown]
# # Python as a Calculator

# %% [markdown]
# Addition

# %%
print(3+7)
# Out:
# 10

# %%
print(3 + 7)
# Out:
# 10

# %% [markdown]
# Subtraction

# %%
print(7-3)
# Out:
# 4

# %%
print(3-7)
# Out:
# -4

# %% [markdown]
# Multiplication

# %%
print(3*8)
# Out:
# 24

# %% [markdown]
# Division

# %%
print(5/2)
# Out:
# 2.5

# %%
print(75/5)
# Out:
# 15.0

# %% [markdown]
# Integer Division

# %%
print(5//2)
# Out:
# 2

# %%
print(8//3)
# Out:
# 2

# %%
print(100//3)
# Out:
# 33

# %% [markdown]
# Power Function

# %%
print(5**3)
# Out:
# 125

# %%
pow(5,3)
# Out:
# 125

# %%
9**0.5
# Out:
# 3.0

# %% [markdown]
# Modulus Function/Symbol

# %%
print(5%3)
# Out:
# 2

# %%
print(68%7)
# Out:
# 5

# %%
print(4%2)
# Out:
# 0

# %%
print((1+2)*3)
# Out:
# 9

# %%
print(1+(2*3))
# Out:
# 7

# %%
0.5*100
# Out:
# 50.0

# %% [markdown]
# Type Function

# %%
type("Sun")
# Out:
# str

# %%
type(187)
# Out:
# int

# %%
type(2.5)
# Out:
# float

# %%
type(True)
# Out:
# bool

# %%
print("4a")
print(3)
print(3.0)
# Out:
# 4a
# 3
# 3.0

# %% [markdown]
# Variables

# %%
age = 3*5

# %%
print(age)
# Out:
# 15

# %%
print(3 * age)
# Out:
# 45

# %%
fruit = "APPLE"
print(fruit)
# Out:
# APPLE

# %%
age = 21
print (age)
# Out:
# 21

# %% [markdown]
# ## Data Structures in Python 3

# %% [markdown]
# List

# %%
[1,2,3,4,5]
# Out:
# [1, 2, 3, 4, 5]

# %%
type([1,2,3,4,5])
# Out:
# list

# %%
mixed = ["fruits",12,2,5,False]

# %%
print(mixed)
type(mixed)
# Out:
# ['fruits', 12, 2, 5, False]
# list

# %% [markdown]
# Python Methods (strings and lists)

# %%
mixed.append(30)

# %%
print(mixed)
# Out:
# ['fruits', 12, 2, 5, False, 30]

# %%
mixed.remove(30)

# %%
print(mixed)
# Out:
# ['fruits', 12, 2, 5, False]

# %%
name = "EDORA"
print("my name is "+ name)
print(f"my name is {name}")
# Out:
# my name is EDORA
# my name is EDORA

# %%
"Hello" + " " + "World"
# Out:
# 'Hello World'

# %%
odd_numbers = [1,3,5,7,9,11,13]
even_numbers = [2,4,6,8,10,12,14]

# %%
print(odd_numbers)
# Out:
# [1, 3, 5, 7, 9, 11, 13]

# %% [markdown]
# Positive Indexing

# %%
print(odd_numbers[0])
print(odd_numbers[1])
print(odd_numbers[2])
print(odd_numbers[5])

odd_numbers_new = odd_numbers + [15,17]
print(odd_numbers_new)
# Out:
# 1
# 3
# 5
# 11
# [1, 3, 5, 7, 9, 11, 13, 15, 17]

# %% [markdown]
# Negative Indexing

# %%
print(odd_numbers[-2])
print(odd_numbers[-1])
# Out:
# 11
# 13

# %%
print(odd_numbers[2:4])
# Out:
# [5, 7]

# %%
type((1,2,3,4))
# Out:
# tuple

# %% [markdown]
# Set/Dictionary

# %%
numbers = {1,2,3,4,5}
print(type(numbers))
# Out:
# <class 'set'>

# %%
contact = {
    "name" : "EDORA",
    "class" : "Data Analysis",
    "age" : 21
}

# %%
print(contact)
type(contact)
# Out:
# {'name': 'EDORA', 'class': 'Data Analysis', 'age': 21}
# dict

# %%
contact = {
    "name" : "EDORA",
    "class" : "Data Analysis",
    "age" : 21
}

# %%
contact.keys()
# Out:
# dict_keys(['name', 'class', 'age'])

# %%
contact.values()
# Out:
# dict_values(['EDORA', 'Data Analysis', 21])

# %% [markdown]
# ### Looping in Python 3

# %%
person = ["victoria", 25,"trader", "korea",[1999,"September",9]]

# %%
for i in person:
  print(i)
# Out:
# victoria
# 25
# trader
# korea
# [1999, 'September', 9]

# %%
for a in even_numbers:
  print(f"{a} is multlied by 2 to give {a*2}")
# Out:
# 2 is multlied by 2 to give 4
# 4 is multlied by 2 to give 8
# 6 is multlied by 2 to give 12
# 8 is multlied by 2 to give 16
# 10 is multlied by 2 to give 20
# 12 is multlied by 2 to give 24
# 14 is multlied by 2 to give 28

# %%
nigerian_players =["Osimhen","Iwobi","A. Adams","Onyeka","Lookman","Nwabill","Bassey","Aina","Bruno"]

# %%
for i in nigerian_players:
  print(i)
# Out:
# Osimhen
# Iwobi
# A. Adams
# Onyeka
# Lookman
# Nwabill
# Bassey
# Aina
# Bruno

# %%
korean_movies = ["Moonshine", "Business Proposal", "Alchemy of Souls", "Fiery Priest", "Jewel in Palace", "Musicians"]

# %%
for k in korean_movies:
  print(k)
# Out:
# Moonshine
# Business Proposal
# Alchemy of Souls
# Fiery Priest
# Jewel in Palace
# Musicians

# %% [markdown]
# While Loop Statement

# %%
countdown = 10

# %%
while countdown > 0:
  print(f"{countdown} seconds left")
  countdown-=1
# Out:
# 10 seconds left
# 9 seconds left
# 8 seconds left
# 7 seconds left
# 6 seconds left
# 5 seconds left
# 4 seconds left
# 3 seconds left
# 2 seconds left
# 1 seconds left

# %% [markdown]
# Conditional Statements
#
# - if
# - elif
# - else

# %%
Age = 16

# %%
if Age >=18:
  print("This is an Adult")
elif Age >=13:
  print("This is a Teenager")
else:
  print("This is a Child")
# Out:
# This is a Teenager

# %%
score = 56

# %%
if score >=70:
  print("A")
elif score >=60:
  print("B")
elif score >=50:
    print("C")
elif score >=45:
  print("D")
else:
  print("f")
# Out:
# C

# %% [markdown]
# # Python Libraris for Data Analysis

# %% [markdown]
# # Numpy - Numerical Python

# %%
import numpy as np

# %%
prime = [1,2,8,7]
type(prime)
# Out:
# list

# %%
prime1 = np.array(prime)
print(prime1)
type(prime1)
# Out:
# [1 2 8 7]
# numpy.ndarray

# %%
prime1.shape
# Out:
# (4,)

# %%
np.mean(prime)
# Out:
# np.float64(4.5)

# %%
np.median(prime)
# Out:
# np.float64(4.5)

# %%
arr1 = [[1,2,3],[4,5,6]]
print(arr1)
# Out:
# [[1, 2, 3], [4, 5, 6]]

# %%
arr1 = np.array(arr)
print(arr1)
# Out:
# [[1 2 3]
#  [4 5 6]]

# %%
arr1.shape
# Out:
# (2, 3)

# %%
np.random.random((2,3))
# Out:
# array([[0.31349309, 0.35779594, 0.83624595],
#        [0.60846275, 0.61253631, 0.22986774]])

# %% [markdown]
# Pandas

# %%
import pandas as pd

# %%
days = pd.Series(["Monday","Tuesday","Wednesday"], index = ["a","b","c"])
print(days)
# Out:
# a       Monday
# b      Tuesday
# c    Wednesday
# dtype: object

# %%
df_dict = {
    "country":["Nigeria","Ghana","Mali","Togo","Algeria"],
    "capital":["Abuja","Accra","Bamako","Lome","Algiers"],
    "population":[300000,150000,100000,30000,50000],
    "AV_age":[23,28,30,35,37]
}

# %%
print(df_dict)
# Out:
# {'country': ['Nigeria', 'Ghana', 'Mali', 'Togo', 'Algeria'], 'capital': ['Abuja', 'Accra', 'Bamako', 'Lome', 'Algiers'], 'population': [300000, 150000, 100000, 30000, 50000], 'AV_age': [23, 28, 30, 35, 37]}

# %%
df = pd.DataFrame(df_dict,index=["a","b","c","d","e"])
print(df)
# Out:
#    country  capital  population  AV_age
# a  Nigeria    Abuja      300000      23
# b    Ghana    Accra      150000      28
# c     Mali   Bamako      100000      30
# d     Togo     Lome       30000      35
# e  Algeria  Algiers       50000      37

# %%
df.reset_index()
# Out:
#   index  country  capital  population  AV_age
# 0     a  Nigeria    Abuja      300000      23
# 1     b    Ghana    Accra      150000      28
# 2     c     Mali   Bamako      100000      30
# 3     d     Togo     Lome       30000      35
# 4     e  Algeria  Algiers       50000      37

# %%
df.iloc[2]
# Out:
# country         Mali
# capital       Bamako
# population    100000
# AV_age            30
# Name: c, dtype: object

# %%
df.loc['a']
# Out:
# country       Nigeria
# capital         Abuja
# population     300000
# AV_age             23
# Name: a, dtype: object

# %%
df["capital"]
# Out:
# a      Abuja
# b      Accra
# c     Bamako
# d       Lome
# e    Algiers
# Name: capital, dtype: object

# %%
df.columns
# Out:
# Index(['country', 'capital', 'population', 'AV_age'], dtype='object')

# %%
df.shape
# Out:
# (5, 4)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 5 entries, a to e
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   country     5 non-null      object
#  1   capital     5 non-null      object
#  2   population  5 non-null      int64
#  3   AV_age      5 non-null      int64
# dtypes: int64(2), object(2)
# memory usage: 372.0+ bytes

# %%
df.describe()
# Out:
#           population    AV_age
# count       5.000000   5.00000
# mean   126000.000000  30.60000
# std    107842.477716   5.59464
# min     30000.000000  23.00000
# 25%     50000.000000  28.00000
# 50%    100000.000000  30.00000
# 75%    150000.000000  35.00000
# max    300000.000000  37.00000
